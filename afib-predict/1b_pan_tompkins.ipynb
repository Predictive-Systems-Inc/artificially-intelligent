# %%
import wfdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from biosppy.signals import ecg

# Set the directory where your PhysioNet data is stored
data_path = "data/training2017"

# Read the reference file (contains labels)
labels_df = pd.read_csv(f'{data_path}/REFERENCE.csv', header=None, names=['record_name', 'label'])

# Given
data_path = "data/training2017"
frequency = 300

# %%
# Test the function with a single record

record_name = 'A00001'

plt.figure(figsize=(15, 15))

record = wfdb.rdrecord(f'{data_path}/{record_name}')
ecg_signal = record.p_signal[:, 0]

out = ecg.ecg(signal=ecg_signal, sampling_rate=300, show=False)
# Print all available keys
print("Available outputs:", out.keys())

# Extract the processed signal and R-peak locations
filtered_ecg = out['filtered']
r_peaks = out['rpeaks']

# Plot the ECG signal with R-peaks
plt.figure(figsize=(12, 6))
plt.plot(filtered_ecg, label="Filtered ECG Signal")
plt.plot(r_peaks, filtered_ecg[r_peaks], "ro", label="R-peaks")  # Mark R-peaks with red dots
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.title("ECG Signal with Detected R-peaks")
plt.legend()
plt.show()
# Out:
# Available outputs: ['ts', 'filtered', 'rpeaks', 'templates_ts', 'templates', 'heart_rate_ts', 'heart_rate']

# %%
# Create a reusable function for Pan-Tompkins algorithm
def compute_pan_tompkins(record_name):
    record = wfdb.rdrecord(f'{data_path}/{record_name}')
    ecg_signal = record.p_signal[:, 0]

    out = ecg.ecg(signal=ecg_signal, sampling_rate=300, show=False)

    filtered_ecg = out['filtered']
    r_peaks = out['rpeaks']
    heart_rate = out['heart_rate']

    # convert r_peaks to seconds
    r_peaks_seconds = r_peaks / frequency

    # Compute RR intervals
    rr_intervals = np.diff(r_peaks_seconds)

    # Compute mean and std of the RR intervals
    rr_mean = np.mean(rr_intervals)
    rr_std = np.std(rr_intervals)
    rmssd = np.sqrt(np.mean(np.square(np.diff(r_peaks_seconds))))

    # Calculate pNN50
    pnn50 = np.sum(np.abs(np.diff(r_peaks_seconds)) > 0.05) / len(rr_intervals)

    # Compute heart rate features
    if len(heart_rate) > 0:
        hr_mean = np.mean(heart_rate)
        hr_std = np.std(heart_rate)
        min_hr = np.min(heart_rate)
        max_hr = np.max(heart_rate)
    else:
        hr_mean = np.nan
        hr_std = np.nan
        min_hr = np.nan
        max_hr = np.nan

    # compute signal features
    signal_power = np.sum(np.square(filtered_ecg))
    signal_entropy = -np.sum(np.square(filtered_ecg) * np.log2(np.square(filtered_ecg)))
    signal_energy = np.sum(np.square(filtered_ecg))
    signal_power = signal_power / len(filtered_ecg)

    # irregularity features
    irregularity_mean = np.mean(np.diff(r_peaks_seconds))
    irregularity_std = np.std(np.diff(r_peaks_seconds))
    rr_coefficient = np.std(rr_intervals) / np.mean(rr_intervals)

    features = {
        'rr_mean': rr_mean,
        'rr_std': rr_std,
        'rmssd': rmssd,
        'pnn50': pnn50,
        'hr_mean': hr_mean,
        'hr_std': hr_std,
        'min_hr': min_hr,
        'max_hr': max_hr,
        'signal_power': signal_power,
        'signal_entropy': signal_entropy,
        'irregularity_mean': irregularity_mean,
        'irregularity_std': irregularity_std,
        'rr_coefficient': rr_coefficient
    }

    return features

# Test the function with a single record
record_name = 'A00001'
features = compute_pan_tompkins(record_name)
print(features)
# Out:
# {'rr_mean': 0.7616666666666667, 'rr_std': 0.033093434977295604, 'rmssd': 0.7623852612358843, 'pnn50': 1.0, 'hr_mean': 78.92296990588672, 'hr_std': 3.0344651188617955, 'min_hr': 74.29686353306778, 'max_hr': 83.60612381061148, 'signal_power': 0.024269070842440114, 'signal_entropy': 500.030759983169, 'irregularity_mean': 0.7616666666666667, 'irregularity_std': 0.033093434977295604, 'rr_coefficient': 0.04344871112992858}

# %%
# Process all the records
all_features = []
for i, record_name in enumerate(labels_df['record_name']):
    features = compute_pan_tompkins(record_name)
    # include the record name and label
    features['record_name'] = record_name
    features['label'] = labels_df[labels_df.record_name == record_name].label.values[0]
    all_features.append(features)
    if i % 10 == 0:
        print(f'Processed {i} records')

# Convert to DataFrame
features_df = pd.DataFrame(all_features)
features_df.to_csv('results/pan_tomkins_features.csv', index=False)
# Out:
# Processed 0 records
# Processed 10 records
# Processed 20 records
# Processed 30 records
# Processed 40 records
# Processed 50 records
# Processed 60 records
# Processed 70 records
# Processed 80 records
# Processed 90 records
# Processed 100 records
# Processed 110 records
# Processed 120 records
# Processed 130 records
# Processed 140 records
# Processed 150 records
# Processed 160 records
# Processed 170 records
# Processed 180 records
# Processed 190 records
# Processed 200 records
# Processed 210 records
# Processed 220 records
# Processed 230 records
# Processed 240 records
# Processed 250 records
# Processed 260 records
# Processed 270 records
# Processed 280 records
# Processed 290 records
# Processed 300 records
# Processed 310 records
# Processed 320 records
# Processed 330 records
# Processed 340 records
# Processed 350 records
# Processed 360 records
# Processed 370 records
# Processed 380 records
# Processed 390 records
# Processed 400 records
# Processed 410 records
# Processed 420 records
# Processed 430 records
# Processed 440 records
# Processed 450 records
# Processed 460 records
# Processed 470 records
# Processed 480 records
# Processed 490 records
# Processed 500 records
# Processed 510 records
# Processed 520 records
# Processed 530 records
# Processed 540 records
# Processed 550 records
# Processed 560 records
# Processed 570 records
# Processed 580 records
# Processed 590 records
# Processed 600 records
# Processed 610 records
# Processed 620 records
# Processed 630 records
# Processed 640 records
# Processed 650 records
# Processed 660 records
# Processed 670 records
# Processed 680 records
# Processed 690 records
# Processed 700 records
# Processed 710 records
# Processed 720 records
# Processed 730 records
# Processed 740 records
# Processed 750 records
# Processed 760 records
# Processed 770 records
# Processed 780 records
# Processed 790 records
# Processed 800 records
# Processed 810 records
# Processed 820 records
# Processed 830 records
# Processed 840 records
# Processed 850 records
# Processed 860 records
# Processed 870 records
# Processed 880 records
# Processed 890 records
# Processed 900 records
# Processed 910 records
# Processed 920 records
# Processed 930 records
# Processed 940 records
# Processed 950 records
# Processed 960 records
# Processed 970 records
# Processed 980 records
# Processed 990 records
# Processed 1000 records
# Processed 1010 records
# Processed 1020 records
# Processed 1030 records
# Processed 1040 records
# Processed 1050 records
# Processed 1060 records
# Processed 1070 records
# Processed 1080 records
# Processed 1090 records
# Processed 1100 records
# Processed 1110 records
# Processed 1120 records
# Processed 1130 records
# Processed 1140 records
# Processed 1150 records
# Processed 1160 records
# Processed 1170 records
# Processed 1180 records
# Processed 1190 records
# Processed 1200 records
# Processed 1210 records
# Processed 1220 records
# Processed 1230 records
# Processed 1240 records
# Processed 1250 records
# Processed 1260 records
# Processed 1270 records
# Processed 1280 records
# Processed 1290 records
# Processed 1300 records
# Processed 1310 records
# Processed 1320 records
# Processed 1330 records
# Processed 1340 records
# Processed 1350 records
# Processed 1360 records
# Processed 1370 records
# Processed 1380 records
# Processed 1390 records
# Processed 1400 records
# Processed 1410 records
# Processed 1420 records
# Processed 1430 records
# Processed 1440 records
# Processed 1450 records
# Processed 1460 records
# Processed 1470 records
# Processed 1480 records
# Processed 1490 records
# Processed 1500 records
# Processed 1510 records
# Processed 1520 records
# Processed 1530 records
# Processed 1540 records
# Processed 1550 records
# Processed 1560 records
# Processed 1570 records
# Processed 1580 records
# Processed 1590 records
# Processed 1600 records
# Processed 1610 records
# Processed 1620 records
# Processed 1630 records
# Processed 1640 records
# Processed 1650 records
# Processed 1660 records
# Processed 1670 records
# Processed 1680 records
# Processed 1690 records
# Processed 1700 records
# Processed 1710 records
# Processed 1720 records
# Processed 1730 records
# Processed 1740 records
# Processed 1750 records
# Processed 1760 records
# Processed 1770 records
# Processed 1780 records
# Processed 1790 records
# Processed 1800 records
# Processed 1810 records
# Processed 1820 records
# Processed 1830 records
# Processed 1840 records
# Processed 1850 records
# Processed 1860 records
# Processed 1870 records
# Processed 1880 records
# Processed 1890 records
# Processed 1900 records
# Processed 1910 records
# Processed 1920 records
# Processed 1930 records
# Processed 1940 records
# Processed 1950 records
# Processed 1960 records
# Processed 1970 records
# Processed 1980 records
# Processed 1990 records
# Processed 2000 records
# Processed 2010 records
# Processed 2020 records
# Processed 2030 records
# Processed 2040 records
# Processed 2050 records
# Processed 2060 records
# Processed 2070 records
# Processed 2080 records
# Processed 2090 records
# Processed 2100 records
# Processed 2110 records
# Processed 2120 records
# Processed 2130 records
# Processed 2140 records
# Processed 2150 records
# Processed 2160 records
# Processed 2170 records
# Processed 2180 records
# Processed 2190 records
# Processed 2200 records
# Processed 2210 records
# Processed 2220 records
# Processed 2230 records
# Processed 2240 records
# Processed 2250 records
# Processed 2260 records
# Processed 2270 records
# Processed 2280 records
# Processed 2290 records
# Processed 2300 records
# Processed 2310 records
# Processed 2320 records
# Processed 2330 records
# Processed 2340 records
# Processed 2350 records
# Processed 2360 records
# Processed 2370 records
# Processed 2380 records
# Processed 2390 records
# Processed 2400 records
# Processed 2410 records
# Processed 2420 records
# Processed 2430 records
# Processed 2440 records
# Processed 2450 records
# Processed 2460 records
# Processed 2470 records
# Processed 2480 records
# Processed 2490 records
# Processed 2500 records
# Processed 2510 records
# Processed 2520 records
# Processed 2530 records
# Processed 2540 records
# Processed 2550 records
# Processed 2560 records
# Processed 2570 records
# Processed 2580 records
# Processed 2590 records
# Processed 2600 records
# Processed 2610 records
# Processed 2620 records
# Processed 2630 records
# Processed 2640 records
# Processed 2650 records
# Processed 2660 records
# Processed 2670 records
# Processed 2680 records
# Processed 2690 records
# Processed 2700 records
# Processed 2710 records
# Processed 2720 records
# Processed 2730 records
# Processed 2740 records
# Processed 2750 records
# Processed 2760 records
# Processed 2770 records
# Processed 2780 records
# Processed 2790 records
# Processed 2800 records
# Processed 2810 records
# Processed 2820 records
# Processed 2830 records
# Processed 2840 records
# Processed 2850 records
# Processed 2860 records
# Processed 2870 records
# Processed 2880 records
# Processed 2890 records
# Processed 2900 records
# Processed 2910 records
# Processed 2920 records
# Processed 2930 records
# Processed 2940 records
# Processed 2950 records
# Processed 2960 records
# Processed 2970 records
# Processed 2980 records
# Processed 2990 records
# Processed 3000 records
# Processed 3010 records
# Processed 3020 records
# Processed 3030 records
# Processed 3040 records
# Processed 3050 records
# Processed 3060 records
# Processed 3070 records
# Processed 3080 records
# Processed 3090 records
# Processed 3100 records
# Processed 3110 records
# Processed 3120 records
# Processed 3130 records
# Processed 3140 records
# Processed 3150 records
# Processed 3160 records
# Processed 3170 records
# Processed 3180 records
# Processed 3190 records
# Processed 3200 records
# Processed 3210 records
# Processed 3220 records
# Processed 3230 records
# Processed 3240 records
# Processed 3250 records
# Processed 3260 records
# Processed 3270 records
# Processed 3280 records
# Processed 3290 records
# Processed 3300 records
# Processed 3310 records
# Processed 3320 records
# Processed 3330 records
# Processed 3340 records
# Processed 3350 records
# Processed 3360 records
# Processed 3370 records
# Processed 3380 records
# Processed 3390 records
# Processed 3400 records
# Processed 3410 records
# Processed 3420 records
# Processed 3430 records
# Processed 3440 records
# Processed 3450 records
# Processed 3460 records
# Processed 3470 records
# Processed 3480 records
# Processed 3490 records
# Processed 3500 records
# Processed 3510 records
# Processed 3520 records
# Processed 3530 records
# Processed 3540 records
# Processed 3550 records
# Processed 3560 records
# Processed 3570 records
# Processed 3580 records
# Processed 3590 records
# Processed 3600 records
# Processed 3610 records
# Processed 3620 records
# Processed 3630 records
# Processed 3640 records
# Processed 3650 records
# Processed 3660 records
# Processed 3670 records
# Processed 3680 records
# Processed 3690 records
# Processed 3700 records
# Processed 3710 records
# Processed 3720 records
# Processed 3730 records
# Processed 3740 records
# Processed 3750 records
# Processed 3760 records
# Processed 3770 records
# Processed 3780 records
# Processed 3790 records
# Processed 3800 records
# Processed 3810 records
# Processed 3820 records
# Processed 3830 records
# Processed 3840 records
# Processed 3850 records
# Processed 3860 records
# Processed 3870 records
# Processed 3880 records
# Processed 3890 records
# Processed 3900 records
# Processed 3910 records
# Processed 3920 records
# Processed 3930 records
# Processed 3940 records
# Processed 3950 records
# Processed 3960 records
# Processed 3970 records
# Processed 3980 records
# Processed 3990 records
# Processed 4000 records
# Processed 4010 records
# Processed 4020 records
# Processed 4030 records
# Processed 4040 records
# Processed 4050 records
# Processed 4060 records
# Processed 4070 records
# Processed 4080 records
# Processed 4090 records
# Processed 4100 records
# Processed 4110 records
# Processed 4120 records
# Processed 4130 records
# Processed 4140 records
# Processed 4150 records
# Processed 4160 records
# Processed 4170 records
# Processed 4180 records
# Processed 4190 records
# Processed 4200 records
# Processed 4210 records
# Processed 4220 records
# Processed 4230 records
# Processed 4240 records
# Processed 4250 records
# Processed 4260 records
# Processed 4270 records
# Processed 4280 records
# Processed 4290 records
# Processed 4300 records
# Processed 4310 records
# Processed 4320 records
# Processed 4330 records
# Processed 4340 records
# Processed 4350 records
# Processed 4360 records
# Processed 4370 records
# Processed 4380 records
# Processed 4390 records
# Processed 4400 records
# Processed 4410 records
# Processed 4420 records
# Processed 4430 records
# Processed 4440 records
# Processed 4450 records
# Processed 4460 records
# Processed 4470 records
# Processed 4480 records
# Processed 4490 records
# Processed 4500 records
# Processed 4510 records
# Processed 4520 records
# Processed 4530 records
# Processed 4540 records
# Processed 4550 records
# Processed 4560 records
# Processed 4570 records
# Processed 4580 records
# Processed 4590 records
# Processed 4600 records
# Processed 4610 records
# Processed 4620 records
# Processed 4630 records
# Processed 4640 records
# Processed 4650 records
# Processed 4660 records
# Processed 4670 records
# Processed 4680 records
# Processed 4690 records
# Processed 4700 records
# Processed 4710 records
# Processed 4720 records
# Processed 4730 records
# Processed 4740 records
# Processed 4750 records
# Processed 4760 records
# Processed 4770 records
# Processed 4780 records
# Processed 4790 records
# Processed 4800 records
# Processed 4810 records
# Processed 4820 records
# Processed 4830 records
# Processed 4840 records
# Processed 4850 records
# Processed 4860 records
# Processed 4870 records
# Processed 4880 records
# Processed 4890 records
# Processed 4900 records
# Processed 4910 records
# Processed 4920 records
# Processed 4930 records
# Processed 4940 records
# Processed 4950 records
# Processed 4960 records
# Processed 4970 records
# Processed 4980 records
# Processed 4990 records
# Processed 5000 records
# Processed 5010 records
# Processed 5020 records
# Processed 5030 records
# Processed 5040 records
# Processed 5050 records
# Processed 5060 records
# Processed 5070 records
# Processed 5080 records
# Processed 5090 records
# Processed 5100 records
# Processed 5110 records
# Processed 5120 records
# Processed 5130 records
# Processed 5140 records
# Processed 5150 records
# Processed 5160 records
# Processed 5170 records
# Processed 5180 records
# Processed 5190 records
# Processed 5200 records
# Processed 5210 records
# Processed 5220 records
# Processed 5230 records
# Processed 5240 records
# Processed 5250 records
# Processed 5260 records
# Processed 5270 records
# Processed 5280 records
# Processed 5290 records
# Processed 5300 records
# Processed 5310 records
# Processed 5320 records
# Processed 5330 records
# Processed 5340 records
# Processed 5350 records
# Processed 5360 records
# Processed 5370 records
# Processed 5380 records
# Processed 5390 records
# Processed 5400 records
# Processed 5410 records
# Processed 5420 records
# Processed 5430 records
# Processed 5440 records
# Processed 5450 records
# Processed 5460 records
# Processed 5470 records
# Processed 5480 records
# Processed 5490 records
# Processed 5500 records
# Processed 5510 records
# Processed 5520 records
# Processed 5530 records
# Processed 5540 records
# Processed 5550 records
# Processed 5560 records
# Processed 5570 records
# Processed 5580 records
# Processed 5590 records
# Processed 5600 records
# Processed 5610 records
# Processed 5620 records
# Processed 5630 records
# Processed 5640 records
# Processed 5650 records
# Processed 5660 records
# Processed 5670 records
# Processed 5680 records
# Processed 5690 records
# Processed 5700 records
# Processed 5710 records
# Processed 5720 records
# Processed 5730 records
# Processed 5740 records
# Processed 5750 records
# Processed 5760 records
# Processed 5770 records
# Processed 5780 records
# Processed 5790 records
# Processed 5800 records
# Processed 5810 records
# Processed 5820 records
# Processed 5830 records
# Processed 5840 records
# Processed 5850 records
# Processed 5860 records
# Processed 5870 records
# Processed 5880 records
# Processed 5890 records
# Processed 5900 records
# Processed 5910 records
# Processed 5920 records
# Processed 5930 records
# Processed 5940 records
# Processed 5950 records
# Processed 5960 records
# Processed 5970 records
# Processed 5980 records
# Processed 5990 records
# Processed 6000 records
# Processed 6010 records
# Processed 6020 records
# Processed 6030 records
# Processed 6040 records
# Processed 6050 records
# Processed 6060 records
# Processed 6070 records
# Processed 6080 records
# Processed 6090 records
# Processed 6100 records
# Processed 6110 records
# Processed 6120 records
# Processed 6130 records
# Processed 6140 records
# Processed 6150 records
# Processed 6160 records
# Processed 6170 records
# Processed 6180 records
# Processed 6190 records
# Processed 6200 records
# Processed 6210 records
# Processed 6220 records
# Processed 6230 records
# Processed 6240 records
# Processed 6250 records
# Processed 6260 records
# Processed 6270 records
# Processed 6280 records
# Processed 6290 records
# Processed 6300 records
# Processed 6310 records
# Processed 6320 records
# Processed 6330 records
# Processed 6340 records
# Processed 6350 records
# Processed 6360 records
# Processed 6370 records
# Processed 6380 records
# Processed 6390 records
# Processed 6400 records
# Processed 6410 records
# Processed 6420 records
# Processed 6430 records
# Processed 6440 records
# Processed 6450 records
# Processed 6460 records
# Processed 6470 records
# Processed 6480 records
# Processed 6490 records
# Processed 6500 records
# Processed 6510 records
# Processed 6520 records
# Processed 6530 records
# Processed 6540 records
# Processed 6550 records
# Processed 6560 records
# Processed 6570 records
# Processed 6580 records
# Processed 6590 records
# Processed 6600 records
# Processed 6610 records
# Processed 6620 records
# Processed 6630 records
# Processed 6640 records
# Processed 6650 records
# Processed 6660 records
# Processed 6670 records
# Processed 6680 records
# Processed 6690 records
# Processed 6700 records
# Processed 6710 records
# Processed 6720 records
# Processed 6730 records
# Processed 6740 records
# Processed 6750 records
# Processed 6760 records
# Processed 6770 records
# Processed 6780 records
# Processed 6790 records
# Processed 6800 records
# Processed 6810 records
# Processed 6820 records
# Processed 6830 records
# Processed 6840 records
# Processed 6850 records
# Processed 6860 records
# Processed 6870 records
# Processed 6880 records
# Processed 6890 records
# Processed 6900 records
# Processed 6910 records
# Processed 6920 records
# Processed 6930 records
# Processed 6940 records
# Processed 6950 records
# Processed 6960 records
# Processed 6970 records
# Processed 6980 records
# Processed 6990 records
# Processed 7000 records
# Processed 7010 records
# Processed 7020 records
# Processed 7030 records
# Processed 7040 records
# Processed 7050 records
# Processed 7060 records
# Processed 7070 records
# Processed 7080 records
# Processed 7090 records
# Processed 7100 records
# Processed 7110 records
# Processed 7120 records
# Processed 7130 records
# Processed 7140 records
# Processed 7150 records
# Processed 7160 records
# Processed 7170 records
# Processed 7180 records
# Processed 7190 records
# Processed 7200 records
# Processed 7210 records
# Processed 7220 records
# Processed 7230 records
# Processed 7240 records
# Processed 7250 records
# Processed 7260 records
# Processed 7270 records
# Processed 7280 records
# Processed 7290 records
# Processed 7300 records
# Processed 7310 records
# Processed 7320 records
# Processed 7330 records
# Processed 7340 records
# Processed 7350 records
# Processed 7360 records
# Processed 7370 records
# Processed 7380 records
# Processed 7390 records
# Processed 7400 records
# Processed 7410 records
# Processed 7420 records
# Processed 7430 records
# Processed 7440 records
# Processed 7450 records
# Processed 7460 records
# Processed 7470 records
# Processed 7480 records
# Processed 7490 records
# Processed 7500 records
# Processed 7510 records
# Processed 7520 records
# Processed 7530 records
# Processed 7540 records
# Processed 7550 records
# Processed 7560 records
# Processed 7570 records
# Processed 7580 records
# Processed 7590 records
# Processed 7600 records
# Processed 7610 records
# Processed 7620 records
# Processed 7630 records
# Processed 7640 records
# Processed 7650 records
# Processed 7660 records
# Processed 7670 records
# Processed 7680 records
# Processed 7690 records
# Processed 7700 records
# Processed 7710 records
# Processed 7720 records
# Processed 7730 records
# Processed 7740 records
# Processed 7750 records
# Processed 7760 records
# Processed 7770 records
# Processed 7780 records
# Processed 7790 records
# Processed 7800 records
# Processed 7810 records
# Processed 7820 records
# Processed 7830 records
# Processed 7840 records
# Processed 7850 records
# Processed 7860 records
# Processed 7870 records
# Processed 7880 records
# Processed 7890 records
# Processed 7900 records
# Processed 7910 records
# Processed 7920 records
# Processed 7930 records
# Processed 7940 records
# Processed 7950 records
# Processed 7960 records
# Processed 7970 records
# Processed 7980 records
# Processed 7990 records
# Processed 8000 records
# Processed 8010 records
# Processed 8020 records
# Processed 8030 records
# Processed 8040 records
# Processed 8050 records
# Processed 8060 records
# Processed 8070 records
# Processed 8080 records
# Processed 8090 records
# Processed 8100 records
# Processed 8110 records
# Processed 8120 records
# Processed 8130 records
# Processed 8140 records
# Processed 8150 records
# Processed 8160 records
# Processed 8170 records
# Processed 8180 records
# Processed 8190 records
# Processed 8200 records
# Processed 8210 records
# Processed 8220 records
# Processed 8230 records
# Processed 8240 records
# Processed 8250 records
# Processed 8260 records
# Processed 8270 records
# Processed 8280 records
# Processed 8290 records
# Processed 8300 records
# Processed 8310 records
# Processed 8320 records
# Processed 8330 records
# Processed 8340 records
# Processed 8350 records
# Processed 8360 records
# Processed 8370 records
# Processed 8380 records
# Processed 8390 records
# Processed 8400 records
# Processed 8410 records
# Processed 8420 records
# Processed 8430 records
# Processed 8440 records
# Processed 8450 records
# Processed 8460 records
# Processed 8470 records
# Processed 8480 records
# Processed 8490 records
# Processed 8500 records
# Processed 8510 records
# Processed 8520 records
